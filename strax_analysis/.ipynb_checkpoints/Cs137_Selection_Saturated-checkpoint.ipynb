# %%
## Imports

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib import colors
from matplotlib.colors import LogNorm
from matplotlib.ticker import AutoMinorLocator

# %matplotlib inline
from scipy.optimize import curve_fit, minimize
import strax
import straxbra
import math
from scipy.special import factorial

# %% [markdown]
# ## Data Import

# %%
## Import Cs-137 and background dataset

run_cs = '00176'  # 00176 - 00179
run_bk = '00175'  # 00175, 00180
filenameprefix = 'run_cs_'+run_cs+'_bkg_'+run_bk
filenameprefix_cs = 'run_'+run_cs
filenameprefix_bk = 'run_'+run_bk

ctx = straxbra.XebraContext()

p_cs = ctx.get_array(run_cs, 'peaks')
p_bk = ctx.get_array(run_bk, 'peaks')

print(p_cs['area'].shape[0])
print(p_bk['area'].shape[0])
print((p_cs['area'].shape[0])/(p_bk['area'].shape[0]))
# Out:
# 1077176
# 232967
# 4.623727824112428

# %% [markdown]
# ## Hist 2D

# %% [markdown]
# ### Area vs width

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

bins_x = np.logspace(1, 6, 100)
bins_y = np.logspace(1, 4, 100)

counts_cs, _, _ = np.histogram2d(p_cs['area'], p_cs['width'][:,5], bins=(bins_x, bins_y))
im = plt.pcolormesh(bins_x, bins_y, counts_cs.T, norm=mpl.colors.LogNorm(), cmap = 'jet')

plt.yscale('log')
plt.xscale('log')

plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad) # -35*mm,35*mm = 70
plt.ylabel('Width [ns]', fontsize = label_size, labelpad = label_pad) # 68.5*mm - 2*0.15*mm
plt.title('$^{137}$Cs with Background', fontsize = title_size, pad = title_pad)

plt.gca().set_aspect('auto', adjustable='box')

# Colorbar
cbar = plt.colorbar()
cbar.outline.set_linewidth(2.2)
cbar.ax.tick_params(direction='in', labelsize=label_size, width=1.2, length=6)
cbar.set_label(label='Counts', fontsize=label_size)

fig.savefig(filenameprefix_cs+"_area_width_unscaled.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

bins_x = np.logspace(1, 6, 100)
bins_y = np.logspace(1, 4, 100)

counts_cs, _, _ = np.histogram2d(p_cs['area'], p_cs['width'][:,5], bins=(bins_x, bins_y))
im = plt.pcolormesh(bins_x, bins_y, counts_cs.T, norm=mpl.colors.LogNorm(), cmap = 'jet', vmax=3e3)

plt.yscale('log')
plt.xscale('log')

plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad) # -35*mm,35*mm = 70
plt.ylabel('Width [ns]', fontsize = label_size, labelpad = label_pad) # 68.5*mm - 2*0.15*mm
plt.title('$^{137}$Cs with Background', fontsize = title_size, pad = title_pad)

plt.gca().set_aspect('auto', adjustable='box')

# Colorbar
cbar = plt.colorbar()
cbar.outline.set_linewidth(2.2)
cbar.ax.tick_params(direction='in', labelsize=label_size, width=1.2, length=6)
cbar.set_label(label='Counts', fontsize=label_size)

fig.savefig(filenameprefix_cs+"_area_width.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

bins_x = np.logspace(1, 6, 100)
bins_y = np.logspace(1, 4, 100)

counts_bk, _, _ = np.histogram2d(p_bk['area'], p_bk['width'][:,5], bins=(bins_x, bins_y))
im = plt.pcolormesh(bins_x, bins_y, counts_bk.T, norm=mpl.colors.LogNorm(), cmap = 'jet')

plt.yscale('log')
plt.xscale('log')

plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad) # -35*mm,35*mm = 70
plt.ylabel('Width [ns]', fontsize = label_size, labelpad = label_pad) # 68.5*mm - 2*0.15*mm
plt.title('Background', fontsize = title_size, pad = title_pad)

plt.gca().set_aspect('auto', adjustable='box')

# Colorbar
cbar = plt.colorbar()
cbar.outline.set_linewidth(2.2)
cbar.ax.tick_params(direction='in', labelsize=label_size, width=1.2, length=6)
cbar.set_label(label='Counts', fontsize=label_size)

fig.savefig(filenameprefix_bk+"_area_width_unscaled.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

bins_x = np.logspace(1, 6, 100)
bins_y = np.logspace(1, 4, 100)

counts_bk, _, _ = np.histogram2d(p_bk['area'], p_bk['width'][:,5], bins=(bins_x, bins_y))
im = plt.pcolormesh(bins_x, bins_y, counts_bk.T, norm=mpl.colors.LogNorm(), cmap = 'jet', vmax=3e3)

plt.yscale('log')
plt.xscale('log')

plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad) # -35*mm,35*mm = 70
plt.ylabel('Width [ns]', fontsize = label_size, labelpad = label_pad) # 68.5*mm - 2*0.15*mm
plt.title('Background', fontsize = title_size, pad = title_pad)

plt.gca().set_aspect('auto', adjustable='box')

# Colorbar
cbar = plt.colorbar()
cbar.outline.set_linewidth(2.2)
cbar.ax.tick_params(direction='in', labelsize=label_size, width=1.2, length=6)
cbar.set_label(label='Counts', fontsize=label_size)

fig.savefig(filenameprefix_bk+"_area_width.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Selection Cs - first attempt

# %%
cut_cond_cs = (p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4) #1e4
cut_cond_bk = (p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4) #1e4

# %%
p_cs_s1 = p_cs[cut_cond_cs]
p_bk_s1 = p_bk[cut_cond_bk]

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

bins_x = np.logspace(1, 6, 100)
bins_y = np.logspace(1, 4, 100)

counts_cs, _, _ = np.histogram2d(p_cs_s1['area'], p_cs_s1['width'][:,5], bins=(bins_x, bins_y))
im = plt.pcolormesh(bins_x, bins_y, counts_cs.T, norm=mpl.colors.LogNorm(), cmap = 'jet', vmax=3e3)

plt.yscale('log')
plt.xscale('log')

plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad) # -35*mm,35*mm = 70
plt.ylabel('Width [ns]', fontsize = label_size, labelpad = label_pad) # 68.5*mm - 2*0.15*mm
plt.title('$^{137}$Cs with Background', fontsize = title_size, pad = title_pad)

plt.gca().set_aspect('auto', adjustable='box')

# Colorbar
cbar = plt.colorbar()
cbar.outline.set_linewidth(2.2)
cbar.ax.tick_params(direction='in', labelsize=label_size, width=1.2, length=6)
cbar.set_label(label='Counts', fontsize=label_size)

fig.savefig(filenameprefix_cs+"_area_width_cutout.png", bbox_inches='tight')
plt.show()

# %%
numerator = p_cs['area_per_channel'][:,1:]
denominator = (p_cs['area']-p_cs['area_per_channel'][:,0])
larger0 = (p_cs['area']-p_cs['area_per_channel'][:,0])>0

HF_all = np.array([numerator[i]/denominator[i] for i in range(len(p_cs)) if larger0[i]])

# %%
np.array([HF_all[:, i].mean() for i in range(7)])
# Out:
# array([0.0163924 , 0.11461159, 0.4638694 , 0.07953929, 0.02079388,
#        0.03676019, 0.26803336], dtype=float32)

# %%
numerator = p_cs_s1['area_per_channel'][:,1:]
denominator = (p_cs_s1['area']-p_cs_s1['area_per_channel'][:,0])
larger0 = (p_cs_s1['area']-p_cs_s1['area_per_channel'][:,0])>0

HF_cut = np.array([numerator[i]/denominator[i] for i in range(len(p_cs_s1)) if larger0[i]])

# %%
np.array([HF_cut[:, i].mean() for i in range(7)])
# Out:
# array([0.0940361 , 0.14994939, 0.1570442 , 0.12515536, 0.07514956,
#        0.12117475, 0.27749068], dtype=float32)

# %% [markdown]
# ## Area histogram

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e5)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e5)] #1e4

bins = np.logspace(2,5,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

plt.yscale('log')
plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)

#plt.xlim(right=3e4)

plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_log_log_full.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

plt.yscale('log')
plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_log_log.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with\nBackground', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

#plt.yscale('log')
plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=1, bbox_to_anchor=(0.99,0.99), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_log_lin.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with\nBackground', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

#plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=1, bbox_to_anchor=(0.99,0.99), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_lin_lin.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with\nBackground', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

#plt.yscale('log')
#plt.xscale('log')
plt.xlim(0,3000)
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=1, bbox_to_anchor=(0.99,0.99), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_lin_lin_zoom.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=1, bbox_to_anchor=(0.99,0.99), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_log_lin.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

plt.xlim(0,3000)
plt.ylim(bottom = 0.9)
plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_log_lin_zoom.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')


plt.yscale('log')
plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_diff_log_log.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')


plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=1, bbox_to_anchor=(0.99,0.99), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_diff_lin_log.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

plt.xlim(0,2600)
plt.ylim(bottom = 10)
plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_diff_lin_log_zoom.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

plt.xlim(0,3000)
plt.ylim(bottom = 5)
plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_diff_lin_log_zoom_2.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

plt.xlim(0,2600)
plt.ylim(bottom = 10)
#plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_diff_lin_lin_zoom.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

plt.xlim(0,3000)
plt.ylim(bottom = 0)
#plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_diff_lin_lin_zoom2.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

#plt.yscale('log')
#plt.xscale('log')
plt.xlim(0,3000)
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=2, bbox_to_anchor=(1.01,1.025), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_withdiff_lin_lin_zoom.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

#plt.yscale('log')
plt.xscale('log')
#plt.xlim(0,3000)
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=2, bbox_to_anchor=(1.01,1.025), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_withdiff_log_lin_zoom.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

#plt.yscale('log')
#plt.xscale('log')
#plt.xlim(0,3000)
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=1, bbox_to_anchor=(0.99,0.99), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_withdiff_lin_lin.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')

plt.yscale('log')
plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=3, bbox_to_anchor=(0.01,0.01), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_withdiff_log_log.png", bbox_inches='tight')
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
#plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot

p_cs_s1 = p_cs[(p_cs['width'][:,5] < 100) & (100 < p_cs['area']) & (p_cs['area'] < 1e4)] #1e4
p_bk_s1 = p_bk[(p_bk['width'][:,5] < 100) & (100 < p_bk['area']) & (p_bk['area'] < 1e4)] #1e4

bins = np.logspace(2,4,100)
bin_centers = 0.5*(bins[1:] + bins[:-1])
bin_fullwidths = (bins[1:] - bins[:-1])

n_cs, _ = np.histogram(p_cs_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_cs/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_cs)/bin_fullwidths, capsize=0, linestyle='', label='$^{137}$Cs with Background', fmt='o')

n_bk, _ = np.histogram(p_bk_s1['area'], bins=bins)
plt.errorbar(bin_centers, n_bk/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt(n_bk)/bin_fullwidths, capsize=0, linestyle='', label='Background', fmt='s')

n_diff = n_cs-n_bk
plt.errorbar(bin_centers, (n_diff)/bin_fullwidths, xerr=bin_fullwidths/np.sqrt(12), yerr=np.sqrt((np.sqrt(n_cs)/bin_fullwidths)**2+(np.sqrt(n_bk)/bin_fullwidths)**2), capsize=0, linestyle='', label='Difference $^{137}$Cs - Background', fmt='o')


plt.xlim(0,3000)
plt.ylim(bottom = 0.9)
plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Counts/pe', fontsize = label_size, labelpad = label_pad)
plt.xlabel('Area [pe]', fontsize = label_size, labelpad = label_pad)


plt.gca().set_aspect('auto', adjustable='box')

# Legend
leg = plt.legend(loc=2, bbox_to_anchor=(1.01,1.025), fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)

fig.savefig(filenameprefix+"_area_hist_withdiff_log_lin_zoom.png", bbox_inches='tight')
plt.show()
